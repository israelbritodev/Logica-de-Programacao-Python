# %% [markdown]
# # Aula 2: Conceitos Básicos

# %% [markdown]
# # Como usar o Google Colab
#
# Assista a este [vídeo](https://www.youtube.com/watch?v=b8O37dWq2f8#t=8m40s) primeiro antes de prosseguir com os assuntos. Ele irá te guiar em como usar o Google Colab, executar códigos em Python e entre outros aspectos.

# %% [markdown]
# # Algoritmo
#
# Um algoritmo é uma descrição lógica, precisa e executável de uma sequência finita de ações para realizar uma tarefa. Por exemplo, uma receita culinária ou um manual de instruções.

# %% [markdown]
# # Linguagem de Programação
#
# Uma linguagem de programação é o meio usado para escrever os algoritmos que especificam o que os computadores devem fazer. As palavras de uma linguagem de programação são as instruções usadas para escrever a lógica de um algoritmo para um computador. Dentre as várias linguagens de programação, iremos usar Python, pois esta é fácil de aprender, amplamente difundida e muito versátil, fornecendo uma boa base para aprender outras linguagens de programação.

# %% [markdown]
# # Fluxo básico de um algoritmo: entrada, processamento e saída
#
# Antes de escrever o algoritmo, é muito importante **focar em compreender o problema**. Para isso, faça três perguntas:
#
# **1) Quais dados são necessários?**
#
# **2) Como esses dados devem ser manipulados?**
#
# **3) Quais dados devem ser retornados?**
#
# Essas três perguntas formam o fluxo básico de um algoritmo e podem ser resumidas como: **entrada, processamento e saída**. Por exemplo, mostre o resultado das quatro operações básicas da matemática entre dois números inteiros e positivos .

# %% [markdown]
# ## Entrada
#
# n1 e n2

# %% [markdown]
# ## Processamento
#
# adição = n1 + n2
#
# subtração = n1 - n2
#
# multiplicação = n1 * n2
#
# divisão = n1 / n2

# %% [markdown]
# ## Saída
#
# resultado da adição, subtração, multiplicação e divisão

# %% [markdown]
# # Variáveis
#
# Toda informação lida (entrada), processada (processamento) ou retornada (saída) por um algoritmo exige a manipulação de dados entre a memória e o processador de um computador. Para isso acontecer, deve-se criar variáveis, as quais correspondem a um pedaço nomeado da memória do computador. Ou seja, uma variável é como uma caixa etiquetada para permitir sua identificação e posterior manipulação. Em Python, variáveis são criadas da seguinte maneira:

# %%
n1 = 20
n2 = 10
adicao = n1 + n2
subtracao = n1 - n2
multiplicacao = n1 * n2
divisao = n1 / n2

# %% [markdown]
# No exemplo acima,  n1, n2, adicao, subtracao, multiplicacao e divisao são nomes de variáveis e o sinal ”=” faz a ação de atribuir um valor para essas variáveis (semelhante ao que ocorre em uma equação matemática).

# %% [markdown]
# ## Tipos de Variáveis
#
# As variáveis manipulam apenas informações que estão de acordo com o seu tipo de dado. O tipo de uma variável determina qual é a sua **classe de valores válidos**, bem como as **manipulações/operações permitidas**. Por exemplo, todas as variáveis acima são do tipo inteiro e, por isso, permitem qualquer operação matemática.
#
# Os tipos primitivos (básicos) em Python são: Inteiro, Float, String e Booleano.
#
# - **Inteiro**: Qualquer número inteiro. Em Python, usamos ***int*** para designar esse tipo de variável.
# - **Float**: Qualquer número com casas decimais. Em Python, usamos ***float*** para designar esse tipo de variável.
# - **String**: Qualquer conjunto de letras, números ou caracteres especiais que estejam entre aspas. Em Python, usamos ***str*** para designar esse tipo de variável.
# - **Booleano**: Representa apenas dois valores, ***True*** ou ***False***. Você entenderá melhor os casos de uso deste tipo na próxima seção.

# %% [markdown]
# **ATENÇÃO:**
#
# - Python distingue variáveis nomeadas com letras maiúsculas de variáveis nomeadas com letras minúsculas. Assim, n1 e N1 **são duas variáveis diferentes (são duas caixas diferentes)**!
# - Em Python, o tipo de uma variável é dinâmico, ou seja, este **muda de acordo com o valor armazenado na variável**. Por exemplo:

# %%
minha_variavel = 10        # linha 01
minha_variavel = 1.5       # linha 02
minha_variavel = "Programe.py" # linha 03
minha_variavel = True      # linha 04

# %% [markdown]
# No exemplo acima, a variável chamada "minha_variavel", em momentos distintos, armazena quatro valores de tipos diferentes: um inteiro (linha 01), um float (linha 02), uma string (linha 03) e um booleano (linha 04). Note que a variável do tipo string (linha 03) têm seu valor entre aspas "", enquanto a variável do tipo float têm casa decimal separada por ponto.

# %% [markdown]
# **ATENÇÃO:**
#
# - Uma variável de um tipo básico/primitivo armazena apenas **01 (um)** valor por vez! Isso ocorre porque esse tipo de variável corresponde a apenas **01 (um)** espaço de memória que só guarda **01 (um)** informação por vez (**uma variável é uma caixa etiquetada que só guarda um objeto por vez**). No exemplo acima, com exceção do último valor atribuído a "minha_variavel", todos os demais foram substituídos pela atribuição seguinte. Portanto, o valor de "minha_variavel" é True e todos os demais valores foram **perdidos**!

# %% [markdown]
# **EXERCÍCIO**
#
# Informe qual é o tipo de cada uma das seguintes variáveis:
#
# ```
# var_1 = False
# var_2 = 0.13
# var_3 = 13
# var_4 = "Python é legal"
# ```

# %% [markdown]
# # Operadores Aritméticos Básicos
#
# | Operador Aritmético | Nome                        | Entrada e Processamento | Saída           |
# |---------------------|----------------------------|-------------------------|-----------------|
# | +                   | Soma                        | `resultado = 5 + 2`     | `resultado = 7` |
# | -                   | Subtração                   | `resultado = 5 - 2`     | `resultado = 3` |
# | *                   | Multiplicação               | `resultado = 5 * 2`     | `resultado = 10` |
# | /                   | Divisão                     | `resultado = 5 / 2`     | `resultado = 2.5` |
# | //                  | Divisão inteira             | `resultado = 5 // 2`    | `resultado = 2` |
# | %                   | Módulo (resto da divisão)   | `resultado = 5 % 2`     | `resultado = 1` |
# | **                  | Exponenciação               | `resultado = 5 ** 2`    | `resultado = 25` |

# %% [markdown]
# Python segue as mesmas regras de precedência para seus operadores matemáticos que a matemática. O acrônimo PEMDAS é uma maneira prática de lembrar a ordem das operações:
#
# **P** = Parênteses
# **E** = Exponenciação
# **M** = Multiplicação ou
# **D** = Divisão
# **A** = Adição ou
# **S** = Subtração

# %% [markdown]
# **ATENÇÃO:**
#
# - Usem parênteses “( )” para linearizar expressões matemáticas e definir a ordem de execução das operações. Por exemplo, a linearização da fórmula de conversão de Fahrenheit para Celsius fica desta forma: C = (F-32)/ 1.8.
#
# ![Untitled.png](data:image/png;base64,...)

# %% [markdown]
# # Entrada e Saída
#
# Os comandos de entrada e saída permitem, respectivamente, obter e exibir informações. Em Python, input é o comando de entrada padrão. Este comando exibe uma mensagem e espera que o usuário digite um valor e pressione a tecla "Enter" para confirmar a entrada de dados. Após isso, o valor digitado será atribuído à variável associada ao input. Por sua vez, print é o comando padrão para exibir mensagens, expressões e/ou valores de variáveis na tela do usuário. Os exemplos a seguir ilustram como de fazer entrada e saída de Strings (valores alfanuméricos) em Python.

# %%
nome = input("Informe o seu nome: ")
sobrenome = input ("Informe o seu sobrenome: ")
nome_sobrenome = nome + " " + sobrenome
print("Seu nome + sobrenome é: ", nome_sobrenome )
# Out:
# Informe o seu nome: Marcelo
# Informe o seu sobrenome: Santana
# Seu nome + sobrenome é  Marcelo Santana

# %%
X = input("Informe o número X: ")
Y = input("Informe o número Y: ")
resultado = X + Y
print("A soma entre X e Y é ", resultado)

# %% [markdown]
# **ATENÇÃO:**
#
# - Os dois exemplos acima usam o operador de adição (+) para retornarem a concatenação/junção de ***Strings,*** por exemplo:
# <br> 1) se nome = “Ana” e sobrenome = “Maria”, então nome_sobrenome = “AnaMaria” (sem espaço!) e <br> 2) se X = “2” e
# Y = “5”, então resultado = “25”.
#
# - Note que a concatenação das strings “2” e ”5” resulta na string “25” e não o número 7. Para manipular números, o Python exige que o tipo do número seja informado antes, por exemplo:

# %%
X = int(input("Informe o número X = ")) # Note que foi usado o tipo int
Y = int(input("Informe o número Y = ")) # Note que foi usado o tipo int
resultado = X + Y
print("A soma entre X e Y é ", resultado)
resultado = X - Y
print("A subtração entre X e Y é ", resultado)
resultado = X * Y
print("A multiplicação entre  X e Y é ", resultado)
resultado = X / Y
print("A divisão entre X e Y é ", resultado)
resultado = X // Y
print("A divisão inteira entre X e Y é ", resultado)
resultado = X % Y
print("O resto da divisão inteira entre X e Y é ", resultado)
resultado = X ** Y
print("X elevado a Y é ", resultado)

# %% [markdown]
# Se X ou Y NÃO FOREM números inteiros (ex. 5 e 2), o exemplo acima retornará um erro. Assim, caso seja necessário trabalhar com números que tenham casas decimais (float), devemos substituir o int pelo float, por exemplo:

# %%
X = float(input("Informe o número X = ")) # Note que foi usado o tipo float
Y = float(input("Informe o número Y = ")) # Note que foi usado o tipo float
resultado = X + Y
print("A soma entre X e Y é ", resultado)
resultado = X - Y
print("A subtração entre X e Y é ", resultado)
resultado = X * Y
print("A multiplicação entre  X e Y é ", resultado)
resultado = X / Y
print("A divisão entre X e Y é ", resultado)
resultado = X // Y
print("A divisão inteira entre X e Y é ", resultado)
resultado = X % Y
print("O resto da divisão inteira entre X e Y é ", resultado)
resultado = X ** Y
print("X elevado a Y é ", resultado)

# %% [markdown]
# No exemplo acima, como X e Y são variáveis do tipo float, estas sempre irão interpretar que os números lidos terão casas decimais. Assim, mesmo que sejam informados os números inteiros 5 e 2 para as variáveis X e Y, estes serão interpretados como os números reais 5.0 e 2.0

# %% [markdown]
# ## Formatando a saída de dados
#
# O programa abaixo tem duas formas parecidas de saída de dados. Diferentemente da primeira, a segunda tem um único par de aspas, **usa o f antes das aspas e coloca as variáveis entre chaves**. Note que `{nome:10} `reserva 10 espaços para exibir o nome; `{salario:5.2f} `permite exibir o salário com duas casas decimais e `{idade+1:3}` reserva 3 espaços para exibir a idade.

# %%
nome = "Rosa"
idade = 20
salario = 10000
print(nome,"      recebe R$",salario,".00 e fará ",idade+1,"anos")
print(f"{nome:10} recebe R$ {salario:5.2f} e fará {idade+1:3} anos")
# Out:
# Rosa       recebe R$ 10000 .00 e fará  21 anos
# Rosa       recebe R$ 10000.00 e fará  21 anos

# %% [markdown]
# # Primeiros Passos com Python

# %% [markdown]
# ## Introdução ao ambiente de desenvolvimento
#
# Para começar a programar em Python, é essencial ter um ambiente de desenvolvimento configurado corretamente. Esse ambiente é onde você irá escrever, testar e depurar o seu código.
#
# Uma das formas mais simples e práticas de começar a programar em Python, especialmente se você não quer se preocupar com a instalação de ferramentas no seu computador, é utilizando o [OnlineGDB](https://www.onlinegdb.com/online_python_compiler). O OnlineGDB é um ambiente de programação online que permite escrever e executar código Python diretamente no navegador, sem a necessidade de instalação de um programa.
#
# Além de ser fácil de usar, o OnlineGDB suporta várias linguagens de programação, tornando-o uma boa escolha para quem está começando ou para quem precisa de um ambiente de desenvolvimento acessível de qualquer lugar.

# %% [markdown]
# ### Acessando o OnlineGDB
#
# 1. **Acesso ao OnlineGDB:**
#     - Abra o navegador e vá para o site oficial do OnlineGDB: https://www.onlinegdb.com/online_python_compiler.
#     - Não é necessário criar uma conta, mas você pode se registrar para salvar seus códigos e projetos online.
# 2. **Criando um novo projeto:**
#     - Ao acessar o site, você já verá um editor de código aberto. O OnlineGDB automaticamente seleciona Python como linguagem, mas você pode verificar isso no menu suspenso no canto superior esquerdo.
#     - Comece a escrever o seu código diretamente na área principal do editor.

# %% [markdown]
# ### Primeiros passos no OnlineGDB
#
# 1. **Escrevendo o primeiro código:**
#     - No editor principal, você pode digitar o seu código Python. Por exemplo, para escrever o famoso "Hello, World!" em Python, basta digitar:
#
#         ```python
#         print("Hello, World!")
#         ```
#
#     - Para executar o código, clique no botão **"Run"** (Executar), de cor verde e localizado no topo da página. O resultado será exibido na área inferior do site.
# 2. **Trabalhando com o editor:**
#     - O OnlineGDB oferece funcionalidades como destaque de sintaxe e autocompletar, que ajudam a melhorar a experiência de programação.
#     - Embora seja simples e direto, ele permite que você adicione arquivos ao projeto, depure o código e até colabore com outras pessoas, tudo dentro do navegador.
# 3. **Salvando seu trabalho:**
#     - Se você estiver registrado, poderá salvar seus códigos diretamente no OnlineGDB clicando em **"Save"** de cor azul e no topo da página. Caso contrário, você pode copiar o código manualmente ou baixá-lo para o seu computador.
#
# Essa ferramenta é prática para começar a aprender Python sem a necessidade de configurações complicadas, permitindo que você foque no aprendizado da linguagem.

# %% [markdown]
# # Comentários em Python
#
# Em Python, usa-se o sustenido ( # ) para comentar uma linha e três apóstrofos (’’’) para iniciar e mais três apóstrofos para encerrar um comentário de várias linhas. Exemplo:

# %%
# isso é um comentários de linha

'''
isso é um
comentário
de várias
linhas
'''

# %% [markdown]
# **ATENÇÃO**
#
# - Os comentários só são vistos por quem analisar o código-fonte, ou seja, estes não aparecem ao executar o programa.

# %% [markdown]
# ## Cuidados ao digitar Programas em Python
#
# - Tenha atenção com aspas e parênteses. Toda vez que abrir aspas ou parêntesis, lembre-se de fechar no lugar certo.
# - Letras maiúsculas e minúsculas são diferentes. Assim, X (maiúsculo) e x (minúsculo) são duas variáveis distintas. Isso também vale para valores entre aspas. Por exemplo, “2” e 2, bem como “Ana” e “ana” são valores distintos. Note que não se usa aspas em variáveis. Isto é, “X” é o valor X (em maiúsculo).

# %% [markdown]
# 💡 **Dicas para iniciar a escrita de programas**
#
# 1. Compreenda a essência do problema (foque no que é importante);
# 2. Pergunte-se:
#     - Quais dados preciso conhecer (entrada)?
#     - Como devo manipular esses dados (processamento)?
#     - O que devo retornar (saída)?
# 3. Teste se a lógica está correta (faça um teste de mesa);
# 4. Execute.
# </aside>

# %% [markdown]
# # Teste de Mesa
#
# O Teste de Mesa é um processo manual que é utilizado para validar a lógica de um determinado algoritmo/programa. Não há uma forma padronizada para fazer teste de mesa. Contudo, no geral deve-se criar uma tabela com a primeira coluna informando o número da linha no programa que está sendo executado e as demais colunas com os nomes de todas as variáveis do programa (ver exemplo abaixo). As linhas dessa tabela serão preenchidas conforme cada linha do programa for sendo sequencialmente executada. Por exemplo, o teste de mesa para o programa que mostra o resultado da aplicação dos operadores aritméticos básicos entre os número inteiros X e Y fica assim:

# %%
X = int(input("Informe o número X = ")) # informar o número 5 - LINHA 01
Y = int(input("Informe o número Y = ")) # informar o número 2 - LINHA 02
resultado = X + Y                       #                     - LINHA 03
print("A soma entre X e Y é ", resultado) #                   - LINHA 04
resultado = X - Y                         #                   - LINHA 05
print("A subtração entre X e Y é ", resultado) #              - LINHA 06
resultado = X * Y                              #              - LINHA 07
print("A multiplicação entre  X e Y é ", resultado) #         - LINHA 08
resultado = X / Y                                   #         - LINHA 09
print("A divisão entre X e Y é ", resultado)        #         - LINHA 10
resultado = X // Y                                  #         - LINHA 11
print("A divisão inteira entre X e Y é ", resultado)#         - LINHA 12
resultado = X % Y                                   #         - LINHA 13
print("O resto da divisão inteira entre X e Y é ", resultado)#- LINHA 14
resultado = X ** Y                                           #- LINHA 15
print("X elevado a Y é ", resultado)                         #- LINHA 16

# %% [markdown]
# | Linha do programa | X  | Y  | Resultado |
# |-------------------|----|----|-----------|
# | 1                | 5  |    |           |
# | 2                | 5  | 2  |           |
# | 3                | 5  | 2  | 7         |
# | 4                | 5  | 2  | 7         |
# | 5                | 5  | 2  | 3         |
# | 6                | 5  | 2  | 3         |
# | 7                | 5  | 2  | 10        |
# | 8                | 5  | 2  | 10        |
# | 9                | 5  | 2  | 2.5       |
# | 10               | 5  | 2  | 2.5       |
# | 11               | 5  | 2  | 2         |
# | 12               | 5  | 2  | 2         |
# | 13               | 5  | 2  | 1         |
# | 14               | 5  | 2  | 1         |
# | 15               | 5  | 2  | 25        |
# | 16               | 5  | 2  | 25        |

# %% [markdown]
# # Exercícios
#
# Faça um programa em Python e um teste de mesa para cada uma das questões abaixo.

# %% [markdown]
# 1. Escreva um programa que leia as 2 notas de um aluno em uma disciplina, depois exiba quantos pontos o aluno ficou distante da nota 10 para cada avaliação, sua média e quantos pontos a média do aluno ficou distante da nota 10.

# %% [markdown]
# 2. Escreva um programa que, dado um dos lados de um quadrado, exiba a sua área e o seu perímetro.

# %% [markdown]
# 3. Faça um programa que, solicite a altura e o raio de um cilindro, calcule o volume total do cilindro (use π=3.14) e exiba esse valor.

# %% [markdown]
# 4. Escreva um programa que receba o nome de uma pessoa e sua idade em anos. O programa deve calcular e exibir a idade da pessoa em meses e dias, considerando que um ano tem 12 meses e um mês tem 30 dias.

# %% [markdown]
# 5. Escreva um programa que receba a idade de uma pessoa em dias. Em seguida, converta essa idade para anos, meses e dias, e exiba o resultado. Para fazer essa conversão, assuma que um ano tem 365 dias e um mês tem 30 dias.

# %% [markdown]
# 6. Escreva um programa que, a partir de um valor de custo e de um valor de venda, mostre o valor do lucro obtido com a venda do produto

# %% [markdown]
# 7. Escreva um programa que, leia um valor de custo e o percentual de lucro desejado, e na sequencia mostre o valor final do produto;

# %% [markdown]
# 8. Escreva um programa que, leia um valor de venda e um percentual de desconto, e depois apresente o valor a ser pago pelo produto e o valor do desconto que foi concedido;

# %% [markdown]
# 9. Considerando que o valor do m² para concretar um piso é R$50. Escreva um programa que leia as medidas de um terreno retangular e informe quanto custa para concretá-lo por inteiro.

# %% [markdown]
# 10. Escreva um programa que leia o salário de uma pessoa, quantas horas ela trabalha por dia e quantos dias ela trabalhou no mês. Em seguida, calcule e exiba quanto essa pessoa recebe por hora.

# %% [markdown]
# 11. Crie um programa que receba uma temperatura em Celsius e, considerando as seguintes fórmulas K=C+273 e F=1,8C+32, exiba a temperatura lida usando as escalas Kelvin (K) e Fahrenheit (F).

# %% [markdown]
# 12. Considerando que em um show: 1) 45% dos ingressos vendidos foram meia-entrada; 2) 55% dos ingressos vendidos foram inteiros; 3)O valor do ingresso inteiro custava R$123,45 e 4) o total de ingressos vendidos foi 6.789. Escreva um programa que calcule e exiba:
#
#     a) A quantidade de ingressos meia-entrada e inteira vendidos.
#
#     b) O valor faturado com cada tipo de ingresso.
#
#     c) O valor total faturado.

# %% [markdown]
# 13. Considerando que a altura de um prédio está para a altura de uma pessoa assim como a sombra de um prédio está para a sombra de uma pessoa (isto é, altura_predio/altura_pessoa = sombra_predio/sombra_pessoa), faça um programa para estimar a altura de um prédio, a partir da leitura da sombra do prédio, da sombra da pessoa e da altura da pessoa.

# %% [markdown]
# 14. Escreva um programa para gerar o invertido de um número com três algarismos
# (exemplo: o invertido de 123 é 321). Dicas:
#
# 1) a unidade de um número é calculada assim: unidade = numero % 10;
#
# 2) a dezena de um número é calculada assim: dezena = (numero // 10) % 10 e
#
# 3) a centena de um número é calculada assim: centena = numero // 100, onde: // retorna o quociente (resultado) de uma divisão inteira e % retorna o resto de uma divisão inteira.

# %% [markdown]
# 15. Escreva um programa que permute (troque) o valor de duas variáveis inteiras. **DICA**: use uma terceira variável para armazenar temporariamente o valor a ser trocado.

# %% [markdown]
# # Exercícios Gravados
#
# Neste [**link**](https://drive.google.com/drive/folders/1FCvFL14qDlURcdX5Oyr1JJ_KmNxBksPH?usp=sharing), você consegue ver os vídeos de todos os exercícios desse módulo sendo resolvidos.
#
# O ideal é assistirem todos, porém se não conseguir, não deixe de assistir o primeiro e o último, são muito importantes.
